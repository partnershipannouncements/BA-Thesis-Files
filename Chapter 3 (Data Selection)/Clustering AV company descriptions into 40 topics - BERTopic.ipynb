# %% [markdown]
# ### Load initial CSV

# %%
import pandas as pd
initial_df = pd.read_csv('..//..//231203_CB_selected companies_ISR.csv',';')

# %%
initial_df.tail()
# Out:
#                             Name                URL       Location  \
# 2551                    Valerann  www.valerann.com/       Tel Aviv
# 2552                 V-HOLA Labs     www.v-hola.com       Tel Aviv
# 2553                   viisights  www.viisights.com       Tel Aviv
# 2554  Automotive Equipment (AEV)  www.aev.co.il/en/       Tel Aviv
# 2555                   Uber Eats   www.ubereats.com  San Francisco
#
#             Country                        Industries  \
# 2551         Israel      Artificial Intelligence (AI)
# 2552         Israel                        Automotive
# 2553         Israel      Artificial Intelligence (AI)
# 2554         Israel                        Automotive
# 2555  United States  Apps, Food Delivery, Mobile Apps
#
#                                          Industry Group  \
# 2551                       Artificial Intelligence (AI)
# 2552                                           Hardware
# 2553                       Artificial Intelligence (AI)
# 2554                                     Transportation
# 2555  Apps, Food and Beverage, Mobile, Software, Tra...
#
#                                             Description  \
# 2551  Valerann empowers road network operators and c...
# 2552  VHOLA is an automotive company developing an e...
# 2553  viisights is a leading innovator of behavioral...
# 2554  Automotive Equipment (AEV) is one of the early...
# 2555  Uber Eats is a food delivery platform that mak...
#
#                         Full Description or Description Dealership  \
# 2551  Valerann empowers road network operators and c...      False
# 2552  VHOLA is an automotive company developing an e...      False
# 2553  viisights is a leading innovator of behavioral...      False
# 2554  Automotive Equipment (AEV) is one of the early...      False
# 2555  Uber Eats is a food delivery platform that mak...     Active
#
#       AV terminology  Transport   Mobility  Status Triangulation?  \
# 2551           False       False     False  Active     Crunchbase
# 2552           False       False     False  Active     Crunchbase
# 2553           False       False     False  Active     Crunchbase
# 2554           False       False     False  Active     Crunchbase
# 2555           False       False     False  Active          Orsay
#
#      Layer_Member  Testing Layer
# 2551          NaN            NaN
# 2552          NaN            NaN
# 2553          NaN            NaN
# 2554          NaN            NaN
# 2555       L4 ATV            NaN

# %% [markdown]
# ### Drop unnecessary Columns

# %%
all_columns = initial_df.columns.unique()
unnecessary_columns = ['Industry Group', 'Description', 'Dealership', 'AV terminology','Transport ','Tesing Layer','Mobility']

# %%
all_columns
# Out:
# Index(['Name', 'URL', 'Location', 'Country', 'Industries', 'Industry Group',
#        'Description', 'Full Description or Description', 'Dealership',
#        'AV terminology', 'Transport ', 'Mobility', 'Status', 'Triangulation?',
#        'Layer_Member', 'Testing Layer'],
#       dtype='object')

# %%
all_columns = initial_df.columns.unique()
unnecessary_columns = ['Industry Group', 'Description', 'Dealership', 'AV terminology', 'Transport ', 'Mobility']

# Drop columns in place
initial_df.drop(labels=unnecessary_columns, axis='columns', inplace=True)

# Now, initial_df has the unnecessary columns dropped
cleaned_df = initial_df.copy(deep=True)

# %%
cleaned_df
# Out:
#                             Name                URL       Location  \
# 0                           Lyft           lyft.com  San Francisco
# 1                           Uber       www.uber.com  San Francisco
# 2                           Bolt            bolt.eu        Tallinn
# 3                           Ioki       ioki.com/en/      Frankfurt
# 4                       Bestmile   www.bestmile.com  San Francisco
# ...                          ...                ...            ...
# 2551                    Valerann  www.valerann.com/       Tel Aviv
# 2552                 V-HOLA Labs     www.v-hola.com       Tel Aviv
# 2553                   viisights  www.viisights.com       Tel Aviv
# 2554  Automotive Equipment (AEV)  www.aev.co.il/en/       Tel Aviv
# 2555                   Uber Eats   www.ubereats.com  San Francisco
#
#             Country                                         Industries  \
# 0     United States  Apps, Mobile Apps, Ride Sharing, Software, Tra...
# 1     United States                                                NaN
# 2           Estonia  Car Sharing, Food Delivery, InsurTech, Mobile ...
# 3           Germany                           Software, Transportation
# 4     United States  Artificial Intelligence (AI), Automotive, Auto...
# ...             ...                                                ...
# 2551         Israel                       Artificial Intelligence (AI)
# 2552         Israel                                         Automotive
# 2553         Israel                       Artificial Intelligence (AI)
# 2554         Israel                                         Automotive
# 2555  United States                   Apps, Food Delivery, Mobile Apps
#
#                         Full Description or Description  \
# 0     Lyft designs, markets, and operates a mobile a...
# 1     Uber develops, markets, and operates a ride-sh...
# 2     Bolt is the first European super-app with a mi...
# 3     Ioki is a technology firm that provides smart ...
# 4     Bestmile is a fleet orchestration platform for...
# ...                                                 ...
# 2551  Valerann empowers road network operators and c...
# 2552  VHOLA is an automotive company developing an e...
# 2553  viisights is a leading innovator of behavioral...
# 2554  Automotive Equipment (AEV) is one of the early...
# 2555  Uber Eats is a food delivery platform that mak...
#
#                                                  Status  \
# 0                                                Active
# 1     Uber develops, markets, and operates a ridesha...
# 2                                                Active
# 3                                                Active
# 4                                                Active
# ...                                                 ...
# 2551                                             Active
# 2552                                             Active
# 2553                                             Active
# 2554                                             Active
# 2555                                             Active
#
#                                          Triangulation? Layer_Member  \
# 0                                                   Own       L4 SAV
# 1                                                 Orsay       L4 SAV
# 2                                            Neckermann       L4 SAV
# 3     https://research.frost.com/assets/1/f0a502e4-4...       L4 SAV
# 4                                                    AV       L3 SAV
# ...                                                 ...          ...
# 2551                                         Crunchbase          NaN
# 2552                                         Crunchbase          NaN
# 2553                                         Crunchbase          NaN
# 2554                                         Crunchbase          NaN
# 2555                                              Orsay       L4 ATV
#
#       Testing Layer
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 2551            NaN
# 2552            NaN
# 2553            NaN
# 2554            NaN
# 2555            NaN
#
# [2556 rows x 10 columns]

# %%
import numpy as np
cleaned_df['Layer_Member'].fillna('', inplace=True)
cleaned_df['Testing Layer'].fillna('', inplace=True)
cleaned_df['Layer_Member'] = cleaned_df['Layer_Member'].replace('-  ', np.nan)

# %% [markdown]
# ### Preprocess Full Description text

# %%
import string
import spacy
nlp = spacy.load('en_core_web_md')

def lemmatize_and_lowercase_and_punctuation(text):
    doc = nlp(text)
    lemmatized_tokens = [token.lemma_.lower() for token in doc if not token.is_stop and token.text not in string.punctuation and token.text not in ['vehicle','vehicles', 'car', 'cars']]
    return ' '.join(lemmatized_tokens)

cleaned_df['Description_preprocessed'] = cleaned_df['Full Description or Description'].apply(lemmatize_and_lowercase_and_punctuation)

# %%
cleaned_df.head(3)
# Out:
#    Name           URL       Location        Country  \
# 0  Lyft      lyft.com  San Francisco  United States
# 1  Uber  www.uber.com  San Francisco  United States
# 2  Bolt       bolt.eu        Tallinn        Estonia
#
#                                           Industries  \
# 0  Apps, Mobile Apps, Ride Sharing, Software, Tra...
# 1                                                NaN
# 2  Car Sharing, Food Delivery, InsurTech, Mobile ...
#
#                      Full Description or Description  \
# 0  Lyft designs, markets, and operates a mobile a...
# 1  Uber develops, markets, and operates a ride-sh...
# 2  Bolt is the first European super-app with a mi...
#
#                                               Status Triangulation?  \
# 0                                             Active            Own
# 1  Uber develops, markets, and operates a ridesha...          Orsay
# 2                                             Active     Neckermann
#
#   Layer_Member Testing Layer  \
# 0       L4 SAV
# 1       L4 SAV
# 2       L4 SAV
#
#                             Description_preprocessed  Assigned_Topic
# 0  lyft design market operate mobile application ...               2
# 1  uber develop market operate ride share mobile ...               2
# 2  bolt european super app mission city people bo...              -1

# %% [markdown]
# ## Load models for BERTtopic

# %%
#conda install -c conda-forge hdbscan

# %%
#pip install -U scikit-learn

# %%
import hdbscan
from bertopic import BERTopic

topic_model = BERTopic(embedding_model = "all-MiniLM-L6-v2")

# %% [markdown]
# # Descriptive

# %% [markdown]
# ### Number of Layer Members in Dataset

# %%
cleaned_df.groupby(by='Layer_Member').count().Name
# Out:
# Layer_Member
#           2514
# L1 ATV      10
# L1 SAV       7
# L2 ATV       6
# L2 SAV       6
# L3 SAV       7
# L4 ATV       2
# L4 SAV       4
# Name: Name, dtype: int64

# %% [markdown]
# ### Count Companies per country

# %%
cleaned_df.groupby(by='Country').count().Name
# Out:
# Country
# Albania                          1
# Austria                         15
# Belgium                         22
# Bulgaria                         2
# Canada                         162
# City of                         10
# Croatia                          5
# Czech Republic                   9
# Denmark                         10
# Estonia                          8
# Finland                          8
# France                          86
# Germany                        181
# Greece                           2
# Hungary                         14
# Iceland                          1
# Ireland                          6
# Isle of Man                      1
# Israel                          81
# Italy                           80
# Latvia                           3
# Lithuania                        3
# Luxembourg                       2
# Norway                          13
# Poland                          14
# Portugal                        10
# Romania                          5
# Scottland                        1
# Serbia                           2
# Slovakia (Slovak Republic)       2
# Slovenia                         3
# Spain                           45
# Sweden                          40
# Switzerland                     38
# The Netherlands                 30
# Turkey                          15
# United Kingdom                 219
# United States                 1407
# Name: Name, dtype: int64

# %% [markdown]
# # Create BERTtopic Clustering Output

# %%
import numpy as np
import pandas as pd
from umap import UMAP
from bertopic import BERTopic

import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

# Assuming topic_model is already definedb

# %%
# Fit BERTopic model to the 'Description_preprocessed' column of copied_df
topics, probabilities = topic_model.fit_transform(cleaned_df['Description_preprocessed'])


# Add the assigned topic column to the original DataFrame
cleaned_df['Assigned_Topic'] = topics

#Instead of accessing deafult HBDSCAN model from BERTopic, make parameters explicit
hdbscan_model = HDBSCAN(min_cluster_size=25, metric='euclidean', cluster_selection_method='eom', prediction_data=True, min_sample = 10)

# Explicitly mention HDBSCAN
print(f"Clustering is performed using HDBSCAN with min_cluster_size={hdbscan_model.min_cluster_size}, "
      f"metric={hdbscan_model.metric}, cluster_selection_method={hdbscan_model.cluster_selection_method}")


# Create topic model
docs = cleaned_df["Description_preprocessed"]
topic_model = BERTopic(embedding_model="all-MiniLM-L6-v2", verbose=True)
topics, _ = topic_model.fit_transform(cleaned_df['Description_preprocessed'])

# Prepare data for plotting
embeddings = topic_model._extract_embeddings(docs, method="document")
umap_model = UMAP(n_neighbors=20, n_components=2, min_dist=0.0, random_state=42, metric='cosine').fit(embeddings)
prob_df = pd.DataFrame(umap_model.embedding_, columns=["x", "y"])
prob_df["topic"] = topics

# Add the assigned topic column to the original DataFrame
cleaned_df['Assigned_Topic_phase_0'] = topics

# Plot parameters
top_n = 40
fontsize = 12

# Slice data
to_plot = prob_df.copy()
to_plot[prob_df.topic >= top_n] = -1
outliers = to_plot.loc[to_plot.topic == -1]
non_outliers = to_plot.loc[to_plot.topic != -1]
# Out:
# 2023-12-04 19:59:20,491 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/80 [00:00<?, ?it/s]
# 2023-12-04 19:59:54,429 - BERTopic - Embedding - Completed ✓
# 2023-12-04 19:59:54,429 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2023-12-04 20:00:05,702 - BERTopic - Dimensionality - Completed ✓
# 2023-12-04 20:00:05,702 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2023-12-04 20:00:05,796 - BERTopic - Cluster - Completed ✓
# 2023-12-04 20:00:05,799 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2023-12-04 20:00:05,968 - BERTopic - Representation - Completed ✓
# 2023-12-04 20:00:06,126 - BERTopic - Embedding - Transforming documents to embeddings.
# Clustering is performed using HDBSCAN with min_cluster_size=25, metric=euclidean, cluster_selection_method=eom
# Batches:   0%|          | 0/80 [00:00<?, ?it/s]
# 2023-12-04 20:00:50,997 - BERTopic - Embedding - Completed ✓
# 2023-12-04 20:00:50,997 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2023-12-04 20:01:09,915 - BERTopic - Dimensionality - Completed ✓
# 2023-12-04 20:01:09,917 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2023-12-04 20:01:10,081 - BERTopic - Cluster - Completed ✓
# 2023-12-04 20:01:10,086 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2023-12-04 20:01:10,400 - BERTopic - Representation - Completed ✓

# %% [markdown]
# ### Show clustering Output

# %%
cmap = matplotlib.colors.ListedColormap(['#FF5722', '#03A9F4', '#4CAF50', '#80CBC4', '#673AB7', '#795548',
                                         '#E91E63', '#212121', '#00BCD4', '#CDDC39', '#AED581', '#FFE082',
                                         '#BCAAA4', '#B39DDB', '#F48FB1'])

# Visualize outliers + inliers

fig, ax = plt.subplots(figsize=(15, 15))
scatter_outliers = ax.scatter(outliers['x'], outliers['y'], c="#E0E0E0", s=1, alpha=.9)
scatter = ax.scatter(non_outliers['x'], non_outliers['y'], c=non_outliers['topic'], s=1, alpha=.9, cmap=cmap)

# Add topic names to clusters
centroids = to_plot.groupby("topic").mean().reset_index().iloc[1:]
for row in centroids.iterrows():
    topic = int(row[1].topic)
    text = f"{topic}: " + "_".join([x[0] for x in topic_model.get_topic(topic)[:2]])
    ax.text(row[1].x, row[1].y * 1.01, text, fontsize=fontsize, horizontalalignment='center')

ax.text(0.99, 0.01, f"BERTopic - Top {top_n} topics", transform=ax.transAxes, horizontalalignment="right", color="black")
plt.xticks([], [])
plt.yticks([], [])
plt.show()

# %%
cleaned_df.shape
# Out:
# (2556, 13)

# %% [markdown]
# # Phase 0

# %% [markdown]
# #### Get information on cluster

# %%
topic_representations = topic_model.get_topic_info()
topic_representations
# Out:
#     Topic  Count                                        Name  \
# 0      -1   1203           -1_company_service_system_provide
# 1       0    109               0_lidar_mapping_survey_aerial
# 2       1    105            1_parking_customer_offer_service
# 3       2     81         2_mobility_transportation_ride_city
# 4       3     75               3_robot_robotic_ai_autonomous
# 5       4     72               4_lidar_laser_sensor_photonic
# 6       5     67          5_trailer_equipment_towing_tractor
# 7       6     62              6_financing_dealership_new_pre
# 8       7     59                 7_vision_camera_ai_computer
# 9       8     58            8_repair_automotive_service_auto
# 10      9     55                 9_tire_wheel_service_repair
# 11     10     48             10_dealer_honda_dealership_audi
# 12     11     46               11_repair_collision_body_dent
# 13     12     43           12_drone_aerial_flight_inspection
# 14     13     42            13_part_engine_exhaust_catalogue
# 15     14     41         14_innovation_capital_stage_startup
# 16     15     37  15_development_software_automotive_product
# 17     16     37     16_navigation_gnss_positioning_inertial
# 18     17     33          17_motorcycle_bike_scooter_bicycle
# 19     18     30             18_marine_boat_underwater_ocean
# 20     19     26            19_self_drive_driving_autonomous
# 21     20     25               20_charge_ev_electric_station
# 22     21     22              21_iot_network_security_angoka
# 23     22     22        22_autonomous_truck_trucking_driving
# 24     23     21                      23_spare_part_sale_new
# 25     24     17                24_wash_washing_cleaning_wax
# 26     25     16    25_agricultural_farming_farm_agriculture
# 27     26     15      26_quickloadz_aurrigo_delivery_airport
# 28     27     14                  27_dodge_ram_jeep_chrysler
# 29     28     14  28_repair_service_transmission_replacement
# 30     29     13                   29_traffic_road_time_real
# 31     30     12          30_insurance_tradewise_rental_sale
# 32     31     12              31_leasing_lease_contract_hire
# 33     32     12             32_ford_lincoln_dealership_sale
# 34     33     12              33_electric_ev_fisker_vehicles
#
#                                        Representation  \
# 0   [company, service, system, provide, technology...
# 1   [lidar, mapping, survey, aerial, surveying, ge...
# 2   [parking, customer, offer, service, buy, quali...
# 3   [mobility, transportation, ride, city, transit...
# 4   [robot, robotic, ai, autonomous, robotics, tec...
# 5   [lidar, laser, sensor, photonic, photonics, ap...
# 6   [trailer, equipment, towing, tractor, truck, d...
# 7   [financing, dealership, new, pre, own, sale, o...
# 8   [vision, camera, ai, computer, system, image, ...
# 9   [repair, automotive, service, auto, maintenanc...
# 10  [tire, wheel, service, repair, automotive, tyr...
# 11  [dealer, honda, dealership, audi, new, sale, b...
# 12  [repair, collision, body, dent, paint, glass, ...
# 13  [drone, aerial, flight, inspection, uav, fly, ...
# 14  [part, engine, exhaust, catalogue, performance...
# 15  [innovation, capital, stage, startup, fund, ve...
# 16  [development, software, automotive, product, s...
# 17  [navigation, gnss, positioning, inertial, gps,...
# 18  [motorcycle, bike, scooter, bicycle, helmet, f...
# 19  [marine, boat, underwater, ocean, unmanned, au...
# 20  [self, drive, driving, autonomous, driverless,...
# 21  [charge, ev, electric, station, charging, fast...
# 22  [iot, network, security, angoka, data, cloud, ...
# 23  [autonomous, truck, trucking, driving, drive, ...
# 24  [spare, part, sale, new, purchase, kia, servic...
# 25  [wash, washing, cleaning, wax, car, wipe, spa,...
# 26  [agricultural, farming, farm, agriculture, far...
# 27  [quickloadz, aurrigo, delivery, airport, load,...
# 28  [dodge, ram, jeep, chrysler, new, sud, rive, s...
# 29  [repair, service, transmission, replacement, e...
# 30  [traffic, road, time, real, intersection, driv...
# 31  [insurance, tradewise, rental, sale, finance, ...
# 32  [leasing, lease, contract, hire, van, rental, ...
# 33  [ford, lincoln, dealership, sale, sales, servi...
# 34  [electric, ev, fisker, vehicles, semi, karma, ...
#
#                                   Representative_Docs
# 0   [point poland luxembourg base hold company dev...
# 1   [duck mapping solutions aerial survey company ...
# 2   [vehicle preparation services ltd vps supply s...
# 3   [curb online mobile software application revol...
# 4   [hangzhou extreme wood technology co. ltd. tec...
# 5   [insight develop akinetic semiconductor laser ...
# 6   [travln toys specialize trailer sale manufactu...
# 7   [gilleland chevrolet auto dealership offer lar...
# 8   [vision guided robotics llc vgr vision softwar...
# 9   [car system automotive company offer repair se...
# 10  [alamo tire auto tire company provide brake re...
# 11  [venice honda dealer service center new honda,...
# 12  [fairfield collision center auto body shop off...
# 13  [skypowerline provide detailed inspection serv...
# 14  [davenports company operate automotive autonom...
# 15  [exponential tech focus venture capital fund i...
# 16  [autosar development partnership manufacturer ...
# 17  [fixposition simplify autonomous navigation in...
# 18  [brother powersport dealer motorcycle dirt bik...
# 19  [ecosub robotics limited company spin planet o...
# 20  [yandex self driving group develop self drive ...
# 21  [charge platform provide tool build operate co...
# 22  [angoka iot security company focus protect m2 ...
# 23  [ike mission truck safe trucker valuable truck...
# 24  [romeoauto automotive company provide new sale...
# 25  [car wash king offer wash experience pride mee...
# 26  [sabanto provide farming service tool accelera...
# 27  [autobon pioneer deliveryos fully automate fre...
# 28  [country chrysler dodge ram jeep dealership of...
# 29  [v&f automotive sales service provide range au...
# 30  [autonomia video datum streaming cloud platfor...
# 31  [gallardo insurance agency take hassle shop au...
# 32  [xlcr vehicle management contract hire leasing...
# 33  [ford motor company canada manufacture sell fo...
# 34  [harbinger commercial electric ev company miss...

# %% [markdown]
# #### Find Clusters of Pre-Labeled Companies

# %%
list_of_prelabeled_phase0 = cleaned_df[cleaned_df['Layer_Member'] != ''][['Name','Layer_Member','Assigned_Topic']]
list_of_prelabeled_phase0.head(4)
# Out:
#    Name Layer_Member  Assigned_Topic
# 0  Lyft       L4 SAV               1
# 1  Uber       L4 SAV               1
# 2  Bolt       L4 SAV              -1
# 3  Ioki       L4 SAV               1

# %%
clusters_of_prelabeled_phase0 = list(list_of_prelabeled_phase0['Assigned_Topic'].unique())
representation_phase0 = topic_representations[topic_representations['Topic'].isin(clusters_of_prelabeled_phase0)]
representation_phase0

#this way, companies from above clustering were found, that ended up in the same clusters as companies that were definitely SAV / ATV by knowledge of author
# Out:
#     Topic  Count                                        Name  \
# 0      -1   1203           -1_company_service_system_provide
# 2       1    105            1_parking_customer_offer_service
# 8       7     59                 7_vision_camera_ai_computer
# 9       8     58            8_repair_automotive_service_auto
# 22     21     22              21_iot_network_security_angoka
# 23     22     22        22_autonomous_truck_trucking_driving
# 29     28     14  28_repair_service_transmission_replacement
#
#                                        Representation  \
# 0   [company, service, system, provide, technology...
# 2   [parking, customer, offer, service, buy, quali...
# 8   [vision, camera, ai, computer, system, image, ...
# 9   [repair, automotive, service, auto, maintenanc...
# 22  [iot, network, security, angoka, data, cloud, ...
# 23  [autonomous, truck, trucking, driving, drive, ...
# 29  [repair, service, transmission, replacement, e...
#
#                                   Representative_Docs
# 0   [point poland luxembourg base hold company dev...
# 2   [vehicle preparation services ltd vps supply s...
# 8   [vision guided robotics llc vgr vision softwar...
# 9   [car system automotive company offer repair se...
# 22  [angoka iot security company focus protect m2 ...
# 23  [ike mission truck safe trucker valuable truck...
# 29  [v&f automotive sales service provide range au...

# %%
clusters_of_prelabeled_phase0
# Out:
# [1, -1, 7, 28, 21, 22, 8]

# %% [markdown]
# ### Save Models

# %%
topic_representations.to_csv('Topic_Repr_34_1555Uhr.csv')

#cluster_frequent_words[['Topic','Count','Representation']]
#cluster_frequent_words

# %%
cleaned_df.to_csv('CompsWithTopics_33_1555Uhr.csv', sep = '|')

#cluster_frequent_words[['Topic','Count','Representation']]
#cluster_frequent_words
